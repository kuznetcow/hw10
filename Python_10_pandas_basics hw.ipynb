# %% [markdown]
# # Основы pandas

# %% [markdown]
# ### Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %% [markdown]
# датасет ml-latest-small.zip

# %%
data_ratings = pd.read_csv('ratings.csv')
#возможно, следующие две строки можно записать одним выражением, но я не нашёл как, вылезала ошибка
rating_5 = data_ratings[ data_ratings.rating == 5 ]
rating_5['movieId'].value_counts().head(1)
# Out:
# 318    153
# Name: movieId, dtype: int64

# %%
data_movies = pd.read_csv('movies.csv')
best_movie = data_movies[ data_movies.movieId == 318 ]
best_movie.head()
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data_power = pd.read_csv('power.csv')
data_power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
data_power_filtered =  data_power[ ((data_power['country'] == 'Latvia') | (data_power['country'] == 'Lithuania') |
                       (data_power['country'] == 'Estonia')) &
                       ((data_power['year'] < 2010) &  (data_power['year'] > 2005)) & 
                       ((data_power['category'] == 4) |(data_power['category'] == 12) | (data_power['category'] == 21)) &
                       (data_power['quantity'] >= 0)]

data_power_filtered['quantity'].sum()
# Out:
# 164555.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
import_page = pd.read_html('https://www.bvb.de/eng/Statistics/Matchdays',encoding='utf-8')

import_page[0]
# Out:
#     Unnamed: 0 Unnamed: 1                      team   P   W   D   L  goals  \
# 0          1.0       (1.)            Bayern München  29  21   4   4  86:28
# 1          2.0       (2.)         Borussia Dortmund  29  18   6   5  80:35
# 2          3.0       (4.)  Borussia Mönchengladbach  29  17   5   7  57:35
# 3          4.0       (5.)          Bayer Leverkusen  29  17   5   7  54:36
# 4          5.0       (3.)    Rasenballsport Leipzig  28  15  10   3  70:29
# 5          6.0       (6.)             VfL Wolfsburg  29  11   9   9  41:36
# 6          7.0       (7.)       TSG 1899 Hoffenheim  29  12   6  11  40:48
# 7          8.0       (8.)       Sport-Club Freiburg  29  10   8  11  38:41
# 8          9.0      (10.)                Hertha BSC  29  10   8  11  43:50
# 9         10.0       (9.)             FC Schalke 04  29   9  10  10  34:46
# 10        11.0      (11.)                1. FC Köln  28  10   4  14  44:52
# ...
